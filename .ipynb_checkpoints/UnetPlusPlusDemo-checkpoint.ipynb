# %%
from model import CreateModel
from model import PrepareImage
Model =CreateModel()

# %%
ImagePath = "5_front.jpg"
ImageInput= PrepareImage(ImagePath)
Predicted = np.where(Model.predict(ImageInput)>0.6 , 1,0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24568\3553588363.py in <module>
# ----> 1 Model =CreateModel()
#       2 Model.load_weights("best_model.hdf5")
#
# ~\AppData\Local\Temp\ipykernel_24568\2930095940.py in CreateModel()
#     107     nestnet_output_4 = Conv2D(1, (1, 1), activation='sigmoid', kernel_initializer = 'he_normal',  name='output_4', padding='same')(conv1_5)
#     108
# --> 109     model = Model([inputs], [nestnet_output_4])
#     110     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LR), loss=bce_dice_loss ,metrics=[dice_coef])
#     111
#
# ~\Anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\smart_cond.py in smart_constant_value(pred)
#      77       pred_value = tensor_util.try_evaluate_constant(pred)
#      78     # pylint: enable=protected-access
# ---> 79   elif pred in {0, 1}:  # Accept 1/0 as valid boolean values
#      80     pred_value = bool(pred)
#      81   elif isinstance(pred, bool):
#
# TypeError: Exception encountered when calling layer 'dropout' (type Dropout).
#
# unhashable type: 'list'
#
# Call arguments received by layer 'dropout' (type Dropout):
#   • inputs=tf.Tensor(shape=(None, 256, 256, 32), dtype=float32)
#   • training=["<KerasTensor: shape=(None, 256, 256, 1) dtype=float32 (created by layer 'output_4')>"]

# %%
# Out:
# 1/1 [==============================] - 1s 699ms/step

# %%
import collections
# intializing the arr


elements_count = collections.Counter(Predicted[0].reshape(1 ,256*256 )[0])

elements_count
# Out:
# Counter({0: 64804, 1: 732})

# %%
plt.imshow(ImageInput[0])
plt.show()
plt.imshow(np.squeeze(Predicted[0]))
plt.show()
